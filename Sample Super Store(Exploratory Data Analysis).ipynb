# %% [markdown]
# # Sample Super Store :

# %% [markdown]
# To Analyze the data we need to install some important libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.datasets import load_diabetes
import math

# %%
file_name = 'SampleSuperstore.csv'
store_df = pd.read_csv(file_name)
store_df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# # Size of Dataset

# %%
store_df.shape
# Out:
# (9994, 13)

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
store_df.sample()
# Out:
#           Ship Mode      Segment        Country     City       State  \
# 735  Standard Class  Home Office  United States  Seattle  Washington
#
#      Postal Code Region         Category Sub-Category   Sales  Quantity  \
# 735        98115   West  Office Supplies      Binders  27.936         4
#
#      Discount  Profit
# 735       0.2  9.4284

# %%
# Lets print last five rows

store_df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# # Let's check the missing values

# %%
store_df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# finding total number of null value in the dataset
print("total number fo null values = ", store_df.isnull().sum().count())
# Out:
# total number fo null values =  13

# %% [markdown]
# Observation:
#
# * There is no null values in the data set.

# %% [markdown]
# # Full Summary Of The Dataframe

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# # Statistical Details

# %%
store_df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Lets check the datatypes of data columns

store_df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# # Find the all columns name from the dataset

# %%
store_df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # Lets check if there are any duplicated in the dataset.

# %%
store_df.duplicated().sum()
# Out:
# 17

# %%
# Remove duplicate values from the dataset
store_df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
store_df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
# Find the correlation
store_df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
# Find the covariance

store_df.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %%
# Lets find the series containing countsof unique values
store_df.value_counts()
# Out:
# Ship Mode       Segment      Country        City           State       Postal Code  Region   Category         Sub-Category  Sales    Quantity  Discount  Profit
# Standard Class  Consumer     United States  Salem          Oregon      97301        West     Office Supplies  Paper         10.368   2         0.2        3.6288      2
# Second Class    Corporate    United States  Chicago        Illinois    60653        Central  Office Supplies  Binders       3.564    3         0.8       -6.2370      2
# Standard Class  Consumer     United States  San Francisco  California  94122        West     Office Supplies  Paper         12.840   3         0.0        5.7780      2
#                                             Los Angeles    California  90036        West     Office Supplies  Paper         19.440   3         0.0        9.3312      2
# ...

# %%
# remove unnecessary columns
col = ['Postal Code']
df_1 = store_df.drop(columns=col,axis=1)

# %%
# Lets check sales by Sub-Category Wise

plt.figure(figsize=(16,8))
plt.xticks(rotation = 45)
plt.bar('Sub-Category','Sales', data=store_df)
plt.show()

# %%
#print(df_1['State'].value_counts())
plt.figure(figsize =(15, 8))
sns.countplot(x = df_1['State'])
plt.xticks(rotation = 90)
plt.show()

# %%
#print(store_df['Sub-Category'].value_counts())
plt.figure(figsize=(16,8))
sns.countplot(x=store_df['Sub-Category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Heat Map Data

# %%
fig, axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(store_df.corr(),annot= True)
plt.show()

# %%
fig, axes = plt.subplots(1,1,figsize=(10,8))
sns.heatmap(store_df.cov(),annot = True)
plt.show()

# %%
sns.countplot(x=store_df['Segment'])
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
sns.countplot(store_df['Region']);
# Out:
# C:\Users\ghods\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(25,12))
sns.barplot(x=store_df['Sub-Category'],y=store_df['Profit'])
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Profit'>

# %%
plt.figure(figsize=(10,7))
sns.lineplot('Discount','Profit',data = store_df,color = 'g',label='Discount')
plt.legend()
# Out:
# C:\Users\ghods\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_1.hist(bins=50, figsize=(15,10))
plt.show()

# %%
figsize = (15,10)
sns.pairplot(df_1,hue='Sub-Category')

# %% [markdown]
# # So now we Grouped or sum of the sales, profit,discount,quantity according every state of region and also according to sub-categories sales

# %%
store_df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
Grouped=pd.DataFrame(store_df.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
# Out:
# C:\Users\ghods\AppData\Local\Temp\ipykernel_3176\240770626.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Grouped=pd.DataFrame(store_df.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())

# %%
Grouped
# Out:
#            Ship Mode      Segment    Category Sub-Category       State  \
# 0        First Class     Consumer   Furniture    Bookcases     Arizona
# 1        First Class     Consumer   Furniture    Bookcases  California
# 2        First Class     Consumer   Furniture    Bookcases    Colorado
# 3        First Class     Consumer   Furniture    Bookcases     Florida
# 4        First Class     Consumer   Furniture    Bookcases     Georgia
# ...              ...          ...         ...          ...         ...
# 2978  Standard Class  Home Office  Technology       Phones       Texas
# 2979  Standard Class  Home Office  Technology       Phones     Vermont
# 2980  Standard Class  Home Office  Technology       Phones    Virginia
# 2981  Standard Class  Home Office  Technology       Phones  Washington
# 2982  Standard Class  Home Office  Technology       Phones   Wisconsin
#
#        Region  Quantity  Discount     Sales    Profit
# 0        West         5      0.70   181.470 -320.5970
# ...

# %% [markdown]
# # sum,mean,min,max,count,median,standard deviation,variance,of each states, country, region of profit

# %%
store_df.groupby("State").Profit.agg(['sum','mean','min','max','count','median','std','var'])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76381.3871   38.171608  -325.5720  1906.4850   2001
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12607.8870  -25.625787 -2929.4845   874.9875    492
# ...

# %%
store_df.groupby("Country").Profit.agg(['sum','mean','min','max','count','median','std','var'])
# Out:
#                        sum       mean       min       max  count  median  \
# Country
# United States  286397.0217  28.656896 -6599.978  8399.976   9994  8.6665
#
#                       std           var
# Country
# United States  234.260108  54877.798055

# %%
store_df.groupby("Region").Profit.agg(['sum','mean','min','max','count','median','std','var'])
# Out:
#                  sum       mean        min        max  count   median  \
# Region
# Central   39706.3625  17.092709 -3701.8928  8399.9760   2323   5.1840
# East      91522.7800  32.135808 -6599.9780  5039.9856   2848   8.1717
# South     46749.4303  28.857673 -3839.9904  3177.4750   1620   9.0720
# West     108418.4489  33.849032 -3399.9800  6719.9808   3203  11.1664
#
#                 std           var
# Region
# Central  291.487465  84964.942066
# East     251.605084  63305.118416
# South    212.893088  45323.466948
# West     174.109081  30313.971920

# %%
x = store_df.iloc[:, [9,10,11,12]].values 
from sklearn.cluster import KMeans

wcss = []


for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = "k-means++",
                   max_iter = 300, n_init= 10, random_state 
= 0).fit(x)
    wcss.append(kmeans.inertia_)
    
    
sns.set_style("whitegrid") 
sns.FacetGrid(store_df, hue ="Sub-Category",height = 6).map(plt.scatter,'Sales','Quantity')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %%
sns.pairplot(df_1)

# %%
fig, axes = plt.subplots(figsize = (10, 10 ))

sns.boxplot(store_df['Sales'])
# Out:
# C:\Users\ghods\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales'>

# %%
fig, axes = plt.subplots(figsize = (10, 10))

sns.boxplot(store_df['Discount'])
# Out:
# C:\Users\ghods\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Discount'>

# %%
fig, axes = plt.subplots(figsize = (10, 10))

sns.boxplot(store_df['Profit'])
# Out:
# C:\Users\ghods\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Profit'>

# %%
Q1 = store_df.quantile(q = 0.25, axis = 0, numeric_only = True, interpolation = 'linear')

Q3 = store_df.quantile(q = 0.75, axis = 0, numeric_only = True, interpolation = 'linear')

# %%
IQR = Q3 - Q1

IQR
# Out:
# Postal Code    66785.00000
# Sales            192.66000
# Quantity           3.00000
# Discount           0.20000
# Profit            27.63525
# dtype: float64

# %%
store_df.value_counts().nlargest().plot(kind = 'bar', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Ship Mode,Segment,Country,City,State,Postal Code,Region,Category,Sub-Category,Sales,Quantity,Discount,Profit'>

# %% [markdown]
# # Scatter Plot

# %%
fig, ax = plt.subplots(figsize = (10, 6))
ax.scatter(store_df['Sales'], store_df['Profit'])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
plt.show()

# %% [markdown]
# # Distribution Plot

# %%
print(store_df['Sales'].describe())
plt.figure(figsize=(9, 5))
sns.distplot(store_df['Sales'], color = 'g',bins = 100, hist_kws = {'alpha':0.4});
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64
# C:\Users\ghods\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #      !!  Thank you  !!

# %% [markdown]
# # helpful recources;
#
# * w3schools.com
# * pandas.pydata.org
# * stackoverflow.com
# * Youtube.com
# * geeksforgeeks.org
